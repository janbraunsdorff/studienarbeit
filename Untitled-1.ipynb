# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
label = [0, 8,    16, 24, 32, 40, 48]
cpu =   [33,   31, 31, 34, 37, 40]
gpu =   [248/60.0, 140/60.0, 90/60.0, 80/60.0, 70/60.0, 60/60.0]

fig, ax = plt.subplots()

plt.plot(cpu)
plt.plot(gpu)
plt.xlabel('Batchsize')
plt.ylabel('Zeit in Minuten')
plt.title('CPU vs. GPU ')
plt.yscale('log')
plt.legend(['CPU', 'GPU'])
ax.set_xticklabels(label)
# Out:
# <ipython-input-16-ff361ba53290>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(label)
# [Text(-1.0, 0, '0'),
#  Text(0.0, 0, '8'),
#  Text(1.0, 0, '16'),
#  Text(2.0, 0, '24'),
#  Text(3.0, 0, '32'),
#  Text(4.0, 0, '40'),
#  Text(5.0, 0, '48'),
#  Text(6.0, 0, '')]
