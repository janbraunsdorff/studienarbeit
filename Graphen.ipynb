# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (16, 5)

# %%
def print_plot(acc, loss, c):
    f = plt.figure()
    ax = f.add_subplot(1, 3, 1)
    plt.plot(acc)
    plt.xlabel('Epochen')
    plt.ylabel('Genauigkeit')
    plt.title('Fehler im Trainigsdaten')
    ax.set_ylim(0, 1000)


    ax = f.add_subplot(1, 3, 2)
    plt.plot(loss)
    plt.xlabel('Epochen')
    plt.ylabel('Fehler')
    plt.title('Durchschnittlicher Fehler in Monaten')
    ax.set_ylim(0, 30)

    ax = f.add_subplot(1, 3, 3)
    for i in c:
        plt.plot(i)
    plt.xlabel('Epochen')
    plt.ylabel('Richtiges Alter %')
    plt.title('Fehlerklassen')
    plt.legend(['C4', 'C12', 'C24'])
    ax.set_ylim(0, 100)

    plt.show()

# %%
def extract(res):
    acc = [r['val_loss']  for r in res]
    loss = [r['val_acc']  for r in res]
    c4 = [(r['c4'] / 1425) * 100 for r in res]
    c12 = [(r['c12']  / 1425) * 100 for r in res]
    c24 = [(r['c24'] / 1425) * 100 for r in res]
    return acc, loss, (c4, c12, c24)

# %%
acc, loss, c = extract(
 [{'val_loss': 204.95530522664387, 'val_acc': 11.261127510094886, 'c4': 347, 'c12': 923, 'c24': 1298}, {'val_loss': 144.3547462463379, 'val_acc': 9.298978086011578, 'c4': 444, 'c12': 1057, 'c24': 1356}, {'val_loss': 131.41678822835286, 'val_acc': 8.801039211436954, 'c4': 480, 'c12': 1070, 'c24': 1365}, {'val_loss': 172.35723139444988, 'val_acc': 10.189301108109827, 'c4': 412, 'c12': 986, 'c24': 1329}, {'val_loss': 195.1820287068685, 'val_acc': 11.440658087321003, 'c4': 309, 'c12': 870, 'c24': 1337}, {'val_loss': 120.06077321370442, 'val_acc': 8.262635321689375, 'c4': 512, 'c12': 1122, 'c24': 1383}, {'val_loss': 139.38799209594725, 'val_acc': 9.069247305754459, 'c4': 449, 'c12': 1057, 'c24': 1360}, {'val_loss': 144.10738143920898, 'val_acc': 9.435998635099391, 'c4': 413, 'c12': 1034, 'c24': 1364}, {'val_loss': 118.9482198079427, 'val_acc': 8.314332606033846, 'c4': 499, 'c12': 1123, 'c24': 1380}, {'val_loss': 132.12186787923176, 'val_acc': 8.756330359343327, 'c4': 527, 'c12': 1053, 'c24': 1372}, {'val_loss': 128.47882817586262, 'val_acc': 8.679060951266626, 'c4': 485, 'c12': 1094, 'c24': 1366}, {'val_loss': 163.14753443400065, 'val_acc': 10.136578631401061, 'c4': 385, 'c12': 968, 'c24': 1360}, {'val_loss': 163.68731994628905, 'val_acc': 10.166725705247934, 'c4': 394, 'c12': 970, 'c24': 1355}, {'val_loss': 116.9042460123698, 'val_acc': 8.140863157312074, 'c4': 516, 'c12': 1098, 'c24': 1387}, {'val_loss': 107.40945180257161, 'val_acc': 7.946041074605903, 'c4': 531, 'c12': 1122, 'c24': 1391}, {'val_loss': 127.39280853271484, 'val_acc': 8.727498018560986, 'c4': 464, 'c12': 1087, 'c24': 1370}, {'val_loss': 105.31950658162435, 'val_acc': 7.826966481287071, 'c4': 549, 'c12': 1129, 'c24': 1394}, {'val_loss': 120.68015530904134, 'val_acc': 8.462031364922572, 'c4': 496, 'c12': 1091, 'c24': 1385}, {'val_loss': 122.6873779296875, 'val_acc': 8.425695345016441, 'c4': 499, 'c12': 1108, 'c24': 1376}, {'val_loss': 105.48229942321777, 'val_acc': 7.804396394527319, 'c4': 546, 'c12': 1146, 'c24': 1391}, {'val_loss': 106.03418401082357, 'val_acc': 7.769756708783333, 'c4': 550, 'c12': 1147, 'c24': 1391}, {'val_loss': 105.85456746419271, 'val_acc': 7.831668825462612, 'c4': 545, 'c12': 1135, 'c24': 1393}, {'val_loss': 110.55085576375326, 'val_acc': 7.965687608056598, 'c4': 535, 'c12': 1144, 'c24': 1388}, {'val_loss': 107.5386563618978, 'val_acc': 7.909318826294907, 'c4': 543, 'c12': 1134, 'c24': 1387}, {'val_loss': 117.94200820922852, 'val_acc': 8.210901680257583, 'c4': 532, 'c12': 1103, 'c24': 1379}, {'val_loss': 110.40893198649088, 'val_acc': 8.008902023476784, 'c4': 518, 'c12': 1129, 'c24': 1386}, {'val_loss': 106.73440450032552, 'val_acc': 7.773039442662037, 'c4': 551, 'c12': 1153, 'c24': 1390}, {'val_loss': 106.17260386149088, 'val_acc': 7.761611453571703, 'c4': 569, 'c12': 1140, 'c24': 1390}, {'val_loss': 115.6857474009196, 'val_acc': 8.153242409409899, 'c4': 524, 'c12': 1114, 'c24': 1384}, {'val_loss': 107.97565561930338, 'val_acc': 7.784583830231366, 'c4': 555, 'c12': 1142, 'c24': 1387}, {'val_loss': 103.68624076843261, 'val_acc': 7.684169637073169, 'c4': 553, 'c12': 1154, 'c24': 1389}, {'val_loss': 103.31725044250489, 'val_acc': 7.633239680107193, 'c4': 558, 'c12': 1152, 'c24': 1388}, {'val_loss': 103.61859792073568, 'val_acc': 7.605527062668943, 'c4': 566, 'c12': 1150, 'c24': 1388}, {'val_loss': 100.40630315144857, 'val_acc': 7.534317460445442, 'c4': 565, 'c12': 1166, 'c24': 1393}, {'val_loss': 101.77080663045247, 'val_acc': 7.578316235421884, 'c4': 568, 'c12': 1149, 'c24': 1392}, {'val_loss': 99.83826497395833, 'val_acc': 7.54975222620097, 'c4': 567, 'c12': 1159, 'c24': 1395}, {'val_loss': 108.63889554341634, 'val_acc': 7.930606157009048, 'c4': 518, 'c12': 1140, 'c24': 1387}, {'val_loss': 101.03403790791829, 'val_acc': 7.5526798391583, 'c4': 564, 'c12': 1166, 'c24': 1389}, {'val_loss': 106.96254247029623, 'val_acc': 7.837149953179889, 'c4': 543, 'c12': 1150, 'c24': 1389}, {'val_loss': 103.69260673522949, 'val_acc': 7.709375264849325, 'c4': 557, 'c12': 1149, 'c24': 1391}, {'val_loss': 103.81845550537109, 'val_acc': 7.678853473097387, 'c4': 548, 'c12': 1150, 'c24': 1393}, {'val_loss': 99.27218577067057, 'val_acc': 7.445621304801015, 'c4': 583, 'c12': 1166, 'c24': 1394}, {'val_loss': 105.8249890645345, 'val_acc': 7.759848919239911, 'c4': 549, 'c12': 1132, 'c24': 1392}, {'val_loss': 97.88899739583333, 'val_acc': 7.39314842922519, 'c4': 596, 'c12': 1171, 'c24': 1392}, {'val_loss': 100.67576319376627, 'val_acc': 7.57598631959973, 'c4': 567, 'c12': 1159, 'c24': 1393}, {'val_loss': 103.44440078735352, 'val_acc': 7.716374229722552, 'c4': 544, 'c12': 1152, 'c24': 1392}, {'val_loss': 98.01313069661458, 'val_acc': 7.456926321862923, 'c4': 570, 'c12': 1164, 'c24': 1396}, {'val_loss': 99.97434412638346, 'val_acc': 7.530364113142995, 'c4': 574, 'c12': 1159, 'c24': 1390}, {'val_loss': 98.90684343973795, 'val_acc': 7.446633410694623, 'c4': 572, 'c12': 1158, 'c24': 1395}, {'val_loss': 101.02835286458334, 'val_acc': 7.554224883606938, 'c4': 570, 'c12': 1152, 'c24': 1391}, {'val_loss': 102.81344401041666, 'val_acc': 7.596410603776123, 'c4': 563, 'c12': 1142, 'c24': 1391}, {'val_loss': 99.88895098368327, 'val_acc': 7.508471925150264, 'c4': 575, 'c12': 1162, 'c24': 1389}, {'val_loss': 99.5892323811849, 'val_acc': 7.46451558175713, 'c4': 575, 'c12': 1165, 'c24': 1394}, {'val_loss': 99.31208890279134, 'val_acc': 7.447677612485307, 'c4': 579, 'c12': 1162, 'c24': 1392}, {'val_loss': 98.96180483500163, 'val_acc': 7.44114356727311, 'c4': 579, 'c12': 1164, 'c24': 1392}]

)
print_plot(acc, loss, c)

# %%
acc, loss, c = extract(
[{'val_loss': 768.4865946451823, 'val_acc': 20.588011607979283, 'c4': 245, 'c12': 575, 'c24': 994}, {'val_loss': 709.7731211344401, 'val_acc': 19.441498896931154, 'c4': 253, 'c12': 654, 'c24': 1021}, {'val_loss': 728.38505859375, 'val_acc': 19.683754072887726, 'c4': 226, 'c12': 619, 'c24': 1042}, {'val_loss': 715.0021647135417, 'val_acc': 19.118032539252077, 'c4': 271, 'c12': 656, 'c24': 1040}, {'val_loss': 659.1024892171224, 'val_acc': 18.21163930423332, 'c4': 293, 'c12': 708, 'c24': 1051}, {'val_loss': 735.2031667073568, 'val_acc': 19.581484165817795, 'c4': 249, 'c12': 645, 'c24': 1037}, {'val_loss': 654.9502939860026, 'val_acc': 18.189318688228877, 'c4': 308, 'c12': 714, 'c24': 1067}, {'val_loss': 671.0643513997396, 'val_acc': 18.450243332650924, 'c4': 267, 'c12': 694, 'c24': 1074}, {'val_loss': 673.6995900472006, 'val_acc': 18.542882873373802, 'c4': 262, 'c12': 680, 'c24': 1061}, {'val_loss': 696.107534790039, 'val_acc': 19.091447017228962, 'c4': 239, 'c12': 648, 'c24': 1040}, {'val_loss': 672.3847157796224, 'val_acc': 18.217926242255203, 'c4': 299, 'c12': 718, 'c24': 1064}, {'val_loss': 644.9199849446615, 'val_acc': 17.730620163016848, 'c4': 290, 'c12': 738, 'c24': 1079}, {'val_loss': 647.2778783162435, 'val_acc': 17.800154344, 'c4': 307, 'c12': 727, 'c24': 1082}, {'val_loss': 637.899755859375, 'val_acc': 17.932192958123757, 'c4': 291, 'c12': 708, 'c24': 1072}, {'val_loss': 652.4601064046224, 'val_acc': 18.549464270020973, 'c4': 254, 'c12': 678, 'c24': 1051}, {'val_loss': 638.0898864746093, 'val_acc': 18.05838075394582, 'c4': 294, 'c12': 710, 'c24': 1080}, {'val_loss': 632.9852142333984, 'val_acc': 17.499021608119058, 'c4': 310, 'c12': 741, 'c24': 1089}, {'val_loss': 656.6293518066407, 'val_acc': 18.61837003833115, 'c4': 270, 'c12': 674, 'c24': 1054}, {'val_loss': 622.0688568115235, 'val_acc': 17.419956227866084, 'c4': 301, 'c12': 763, 'c24': 1075}, {'val_loss': 659.4356862386068, 'val_acc': 18.093909030972103, 'c4': 302, 'c12': 724, 'c24': 1071}, {'val_loss': 640.2916290283204, 'val_acc': 17.56200204858876, 'c4': 297, 'c12': 757, 'c24': 1086}, {'val_loss': 627.1693918863932, 'val_acc': 17.465832235716807, 'c4': 317, 'c12': 741, 'c24': 1090}, {'val_loss': 631.1921427408854, 'val_acc': 17.54682392279307, 'c4': 303, 'c12': 743, 'c24': 1078}, {'val_loss': 624.7905939737956, 'val_acc': 17.3629656119178, 'c4': 315, 'c12': 774, 'c24': 1077}, {'val_loss': 617.3902791341146, 'val_acc': 17.213522623765346, 'c4': 324, 'c12': 758, 'c24': 1093}, {'val_loss': 635.8596811930339, 'val_acc': 17.43029219622564, 'c4': 332, 'c12': 758, 'c24': 1092}, {'val_loss': 598.2365341186523, 'val_acc': 16.88812414166903, 'c4': 337, 'c12': 760, 'c24': 1089}, {'val_loss': 625.4070149739583, 'val_acc': 17.36204518970817, 'c4': 308, 'c12': 753, 'c24': 1084}, {'val_loss': 611.5025344848633, 'val_acc': 17.235020297464697, 'c4': 317, 'c12': 759, 'c24': 1091}, {'val_loss': 632.7476654052734, 'val_acc': 17.922812051724904, 'c4': 277, 'c12': 707, 'c24': 1070}, {'val_loss': 619.2536122639974, 'val_acc': 17.22395616083434, 'c4': 304, 'c12': 762, 'c24': 1100}, {'val_loss': 610.9024531046549, 'val_acc': 17.00783165344084, 'c4': 334, 'c12': 780, 'c24': 1092}, {'val_loss': 605.7521128336589, 'val_acc': 17.02170083715458, 'c4': 330, 'c12': 773, 'c24': 1101}, {'val_loss': 604.4463277180989, 'val_acc': 16.93905885508566, 'c4': 326, 'c12': 779, 'c24': 1108}, {'val_loss': 621.4087198893229, 'val_acc': 17.094711540684553, 'c4': 316, 'c12': 766, 'c24': 1099}, {'val_loss': 618.6032063802083, 'val_acc': 17.12228421972255, 'c4': 331, 'c12': 772, 'c24': 1093}, {'val_loss': 620.8056772867839, 'val_acc': 17.501306725511647, 'c4': 299, 'c12': 737, 'c24': 1087}, {'val_loss': 598.303651936849, 'val_acc': 16.856289194328614, 'c4': 326, 'c12': 779, 'c24': 1102}, {'val_loss': 589.097341410319, 'val_acc': 16.947524660765524, 'c4': 326, 'c12': 766, 'c24': 1093}, {'val_loss': 600.7405339558919, 'val_acc': 17.076902863834842, 'c4': 315, 'c12': 777, 'c24': 1099}, {'val_loss': 600.9799753824869, 'val_acc': 16.999728250623953, 'c4': 331, 'c12': 754, 'c24': 1094}, {'val_loss': 594.6672668457031, 'val_acc': 16.96090435476014, 'c4': 322, 'c12': 773, 'c24': 1093}, {'val_loss': 609.1109873453776, 'val_acc': 17.24316355014088, 'c4': 330, 'c12': 756, 'c24': 1088}, {'val_loss': 615.6579355875651, 'val_acc': 17.02722351575138, 'c4': 331, 'c12': 781, 'c24': 1099}, {'val_loss': 601.4318720499674, 'val_acc': 16.974231792218756, 'c4': 335, 'c12': 780, 'c24': 1099}, {'val_loss': 606.9307840983073, 'val_acc': 17.205383690198264, 'c4': 321, 'c12': 757, 'c24': 1089}, {'val_loss': 604.4662221272787, 'val_acc': 16.988725248250095, 'c4': 326, 'c12': 787, 'c24': 1099}, {'val_loss': 604.0502217610677, 'val_acc': 16.882226189579622, 'c4': 329, 'c12': 786, 'c24': 1110}, {'val_loss': 595.9482808430989, 'val_acc': 16.870327056056322, 'c4': 334, 'c12': 776, 'c24': 1104}, {'val_loss': 599.6281443277995, 'val_acc': 16.89453850310258, 'c4': 332, 'c12': 772, 'c24': 1104}, {'val_loss': 604.5240458170573, 'val_acc': 16.867248186559387, 'c4': 342, 'c12': 786, 'c24': 1104}, {'val_loss': 597.6877888997395, 'val_acc': 16.785704561556226, 'c4': 355, 'c12': 786, 'c24': 1104}, {'val_loss': 596.8673858642578, 'val_acc': 16.83253288798862, 'c4': 341, 'c12': 776, 'c24': 1104}, {'val_loss': 593.9397603352865, 'val_acc': 16.793116363010018, 'c4': 333, 'c12': 772, 'c24': 1103}, {'val_loss': 594.9416722615559, 'val_acc': 16.818397469472405, 'c4': 336, 'c12': 780, 'c24': 1101}, {'val_loss': 592.8818379720052, 'val_acc': 16.79557463629077, 'c4': 347, 'c12': 785, 'c24': 1105}, {'val_loss': 602.2232915242513, 'val_acc': 16.808586788538733, 'c4': 340, 'c12': 794, 'c24': 1113}, {'val_loss': 595.7480092366536, 'val_acc': 16.90070786861458, 'c4': 330, 'c12': 776, 'c24': 1095}, {'val_loss': 591.3089955647787, 'val_acc': 16.7953151883501, 'c4': 337, 'c12': 781, 'c24': 1099}, {'val_loss': 591.9606781005859, 'val_acc': 16.82714890638987, 'c4': 320, 'c12': 784, 'c24': 1102}, {'val_loss': 596.3521855672201, 'val_acc': 16.81312511725859, 'c4': 345, 'c12': 784, 'c24': 1106}, {'val_loss': 598.5771443684896, 'val_acc': 16.77837126399531, 'c4': 327, 'c12': 784, 'c24': 1110}, {'val_loss': 598.6478520711263, 'val_acc': 16.83386429993793, 'c4': 340, 'c12': 794, 'c24': 1105}, {'val_loss': 591.9413004557292, 'val_acc': 16.75669402004492, 'c4': 343, 'c12': 795, 'c24': 1111}, {'val_loss': 595.5219807942708, 'val_acc': 16.789712667344794, 'c4': 329, 'c12': 794, 'c24': 1111}, {'val_loss': 596.5617080688477, 'val_acc': 16.865456801953943, 'c4': 330, 'c12': 783, 'c24': 1107}, {'val_loss': 598.3374237060547, 'val_acc': 16.769699814343692, 'c4': 328, 'c12': 793, 'c24': 1114}, {'val_loss': 595.217441813151, 'val_acc': 16.82796628053742, 'c4': 334, 'c12': 793, 'c24': 1107}, {'val_loss': 595.8555531819661, 'val_acc': 16.796590273428443, 'c4': 339, 'c12': 783, 'c24': 1108}, {'val_loss': 591.5581710815429, 'val_acc': 16.774787907287322, 'c4': 340, 'c12': 778, 'c24': 1102}, {'val_loss': 596.0402374267578, 'val_acc': 16.745318797381238, 'c4': 344, 'c12': 782, 'c24': 1106}, {'val_loss': 592.5994791666667, 'val_acc': 16.813561158348815, 'c4': 340, 'c12': 774, 'c24': 1104}, {'val_loss': 591.9614196777344, 'val_acc': 16.787413637927084, 'c4': 342, 'c12': 784, 'c24': 1106}, {'val_loss': 590.992241414388, 'val_acc': 16.76816455210098, 'c4': 349, 'c12': 784, 'c24': 1102}, {'val_loss': 594.1601165771484, 'val_acc': 16.771757700949003, 'c4': 345, 'c12': 781, 'c24': 1108}, {'val_loss': 591.5377400716146, 'val_acc': 16.750631919653728, 'c4': 336, 'c12': 794, 'c24': 1108}, {'val_loss': 593.5461212158203, 'val_acc': 16.798181318875514, 'c4': 342, 'c12': 787, 'c24': 1101}, {'val_loss': 595.7920328776041, 'val_acc': 16.821075406580256, 'c4': 338, 'c12': 778, 'c24': 1108}, {'val_loss': 597.0031758626302, 'val_acc': 16.761397569829764, 'c4': 344, 'c12': 788, 'c24': 1112}, {'val_loss': 595.5967803955078, 'val_acc': 16.783895214519116, 'c4': 343, 'c12': 790, 'c24': 1110}]
)
print_plot(acc, loss, c)
